# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from vec2mat import vec2mat
from show_ordered_map import show_ordered_map
from show_ordered_map_v2 import show_ordered_map_v2
from show_ordered_map_grid import show_ordered_map_grid
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
var1 = np.random.random(5460)
print(var1.shape)

var_correlated = vec2mat(var1)
print(var_correlated.shape)

# %reload_ext autoreload
range_val = (-1, 1)
show_ordered_map(var_correlated)
# Out:
# (5460,)
# (105, 105)

# %%
# %reload_ext autoreload
show_ordered_map_v2(var_correlated, 
                cmap='coolwarm',  # or 'seismic', 'coolwarm'
                # cmap='RdBu_r',  # or 'seismic', 'coolwarm'
                show_boundaries=True)

# %%
# Example data
maps = [var_correlated for _ in range(24)]  # List of 6 correlation matrices
titles = [f'Subject {i+1}' for i in range(24)]

show_ordered_map_grid(maps, 
                     titles=titles,
                     grid_shape=(4,6),
                     range_val=(-1,1),
                     cmap='coolwarm',
                     figsize=(30,20),
                     save_path="results3",
                     save_format="png",
                     dpi=300)
# Out:
# Figure saved as: c:\GSU Dropbox Dropbox\Mohammad Moein Esfahani\myResearch\project_visualization\figures\results3.png
